# %%
from training_function import *

# %%
list_results = []

alg1_result = train_model(
    dataset_name = 'MNIST', # ['MNIST', 'FACES', 'CURVES']
    home_path = '/home/jupyter/',
    algorithm = 'K-BFGS', # ['KFAC', 'K-BFGS', 'K-BFGS(L)', 'RMSprop', 'Adam', 'SGD-momentum']
    lr = 0.3,
    lambda_damping = 0.3,
    batch_size = 1000,
    RMSprop_epsilon = 1e-4,
    if_gpu = True,
    if_max_epoch = 0,
    max_epoch = 100,
    max_cpu_time = 500,
    verbose = True)

list_results += [alg1_result]

alg2_result = train_model(
    dataset_name = 'MNIST', # ['MNIST', 'FACES', 'CURVES']
    home_path = '/home/jupyter/',
    algorithm = 'KFAC', # ['KFAC', 'K-BFGS', 'K-BFGS(L)', 'RMSprop', 'Adam', 'SGD-momentum']
    lr = 0.3,
    lambda_damping = 0.3,
    batch_size = 1000,
    RMSprop_epsilon = 1e-4,
    if_gpu = True,
    if_max_epoch = 0,
    max_epoch = 100,
    max_cpu_time = 500,
    verbose = True)

list_results += [alg2_result]
# Out:
# name_loss:
# logistic-regression-sum-loss
# Model created.
# Begin laoding data...
# Extracting ../data/MNIST_data/train-images-idx3-ubyte.gz
# Extracting ../data/MNIST_data/t10k-images-idx3-ubyte.gz
# Begin training...
# Learning rate: 0.30000
# Epoch-1.000
# Training loss: 170.977
# Training accuracy: 0.052
# Testing loss: 169.955
# Testing accuracy: 0.051
#
#
# Learning rate: 0.30000
# Epoch-2.000
# Training loss: 104.400
# Training accuracy: 0.023
# Testing loss: 103.406
# Testing accuracy: 0.023
#
#
# Learning rate: 0.30000
# Epoch-3.000
# Training loss: 80.411
# Training accuracy: 0.013
# Testing loss: 79.713
# Testing accuracy: 0.013
#
#
# Learning rate: 0.30000
# Epoch-4.000
# Training loss: 70.368
# Training accuracy: 0.009
# Testing loss: 70.199
# Testing accuracy: 0.009
#
#
# Learning rate: 0.30000
# Epoch-5.000
# Training loss: 66.085
# Training accuracy: 0.007
# Testing loss: 66.290
# Testing accuracy: 0.007
#
#
# Learning rate: 0.30000
# Epoch-6.000
# ...

# %%
# %matplotlib inline
from plot_utils import *

# %%
plot_results(list_results)
